# %% [markdown]
# First of all let us import our necessary libraries we shall use in this project

# %% [markdown]
# We shall install pandas for reading and loading our datasets to pandas dataframes, numpy for mathematical operations and plotting of garphs, seaborn for plotting visualizations also and sqlite3 for querying data from databases

# %%
#importing important liraries
import pandas as pd
from matplotlib import pyplot  as plt
import numpy as np
import seaborn as sns
import sqlite3

# %% [markdown]
# Now lets load our bom.movie.gross.csv

# %%
#loading our data bom.movie.gross
bom_data = pd.read_csv("/home/ezzy/Desktop/Phase1_project/bom.movie_gross.csv")
bom_data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# How does the data set look like? We can answer this question by looking at the shape.

# %%
#checking the shape of our data set
bom_data.shape
# Out:
# (3387, 5)

# %% [markdown]
# Now we have our shape and we can see our dataset has 3387 rows and 5 columns of data.
# We can further inspect our data set to see how records are there in total and what data
# type do they contain.

# %%
#checking the information about our data set
bom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# Voila! We now have a general view of how our data set looks like. We can see number of values and type of datatype
# in each record. Our data set contains three types of datatype namely; float, integer and object. We can also see see
# the amount of memory size our data  set occupies in our memory. You can also see that some records having missing values
# and this can be crucial in understanding our data set.

# %% [markdown]
# After having general knowledge on how our data set looks like, we can further get summary statistics from the set
# to gain further insight about the data we are working with. Here we will use the .describe module in python.

# %%
#doing summariy statistics of numeric values in our data set
bom_data.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# 2. MOVIE_BASICS TABLE

# %% [markdown]
# Now lets check the other data sets.
# Now that we know how our first data set looks like, we can first inspect our other data set before we start cleaning.
# Next we are going to load our im.db database and open a connection using the sqlite3 library

# %% [markdown]
# First we are going to start with the "movie_basics" table

# %%
# creates a connection to our dataset
conn = sqlite3.connect("im.db")

# %%
#selecting "movie_basics" table  from our database and converting into a pandas dataFrame
qu = """
SELECT *
FROM movie_basics; 
"""
tables_basics = pd.read_sql(qu, conn)

tables_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# checking how our data set looks like

# %%
#checking the information of our data set
tables_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# 2.1 Shape
#
# let us inspect its shape

# %%
#checking the shape of our data set
tables_basics.shape
# Out:
# (146144, 6)

# %% [markdown]
# It has 146144 rows and 6 columns of data
#
# Lets further  dig into it to get a better understanding

# %% [markdown]
# Now we have a better view of what we are dealing with. We csn see some columns contain null values and this is good data heuristics. We have to deal with the missing values depending on the column. Missing values can be a communication to us, so its better not to ignore it . Our data type also contains three types of data type and covers 6.7 megabytes of our memory

# %% [markdown]
# 2.3 Summary_statistics
#
# To understand how to deal with missing data, we can further calculate the summary statistics of our dataset in order to get a good foundation on where to start

# %%
#checking the summary statistics of numeric columns in our data set
tables_basics.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %% [markdown]
# Now we know the distribution of our data set and we can start dealing with missing data. Before we start cleaning the data, we can also notice that our column "runtime_minutes" has extreme outliers, where we have the min runtime = 1min and max runtime = 51420 min which is not practical or viable in real life situation

# %% [markdown]
# 2.4 CLEANING THE DATA

# %% [markdown]
# Lets start with our runtime column. We can see that it has 114405 records out of 146144 records. That is quite huge data and we cannot ignore it nor drop the column.
# Using the descriptive data we can see runtime mean is significantly almost equal the runtime median. This means the distribution is normal and we can use the mean to replace the missing values

# %%
#calculate the mean of runtime_minutes
mean_runtime = tables_basics["runtime_minutes"].mean()
#replace the missing values in run_time column with the mean
runtime_minutes = tables_basics["runtime_minutes"].fillna(mean_runtime, inplace= True)

# %% [markdown]
# "original_title column contains the same values as "primary_title"

# %%
#checking whether the two columns have the same values
tables_basics["original_title"] == tables_basics["primary_title"]
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 146139     True
# 146140     True
# 146141     True
# 146142     True
# 146143     True
# Length: 146144, dtype: bool

# %%
# dropping one table permanently
tables_basics.drop("original_title", axis=1, inplace=True)

# %% [markdown]
# Dropping the duplicates on the "primary_title" column

# %%
tables_basics.drop_duplicates(subset="primary_title")
# Out:
#          movie_id                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# ...

# %% [markdown]
# Dropping the null values

# %%
#drops null values on the "original_title" column
tables_basics.dropna(subset= "primary_title")
# Out:
#          movie_id                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# ...

# %% [markdown]
# First let us check for duplicate values

# %%
genre_clean = tables_basics["genres"].duplicated().sum()
genre_clean
# Out:
# 145058

# %% [markdown]
# We can see have we have a lot of duplicates on the genre column. This can be an indication that our movies are of many genres and they appear several times within the records. We shall not drop the duplicates because it will help us get insight as we get deeper

# %% [markdown]
# runtime seems to have an outlier. The max value returned on the runtime_minutes column is 51420, which in real life is not practical. Let us use a box plot to check if the column has more outliers.

# %%
#plotting plot using seaborn
run_min_bplot, ax = plt.subplots(figsize =(10,8))
sns.boxplot(tables_basics["runtime_minutes"])
plt.title("Runtime_minutes analysis using  a box plot")
plt.show()

# %% [markdown]
# From the above box plot we can note we have another outlier apart from the one we had seen earlier. Apart from the two, the other data is well distributed that is why we see a small figure like an arrow and a line running. This is because the outliers has caused our scale to use huge plots so that it can be accommodated in the box plot.

# %% [markdown]
# We can hide the outliers to see the distribution better. We shall just pass the arguments "showfliers = False"

# %%
#plotting plot using seaborn
run_min_bplot, ax = plt.subplots(figsize =(10,6))
sns.boxplot(tables_basics["runtime_minutes"], showfliers = False, color = "Green")
plt.ylabel("minutes")
plt.title("Runtime_minutes analysis using  a box plot")
plt.show()

# %% [markdown]
# Perfecto!!! Now we have a full understanding of how our data trully looks like. From the box plot we can get insights like mean, and the quartiles

# %% [markdown]
# To get rid of outliers we will use the interquartile range method, where lower limit = IQR *1.5 upper limit = IQR * 1.5

# %%
low_quant = tables_basics["runtime_minutes"].quantile(0.25)
upp_quant = tables_basics["runtime_minutes"].quantile(0.75)

IQR = upp_quant - low_quant

low_limit = low_quant - 1.5 * IQR
upp_limit = upp_quant + 1.5 * IQR

tables_basics["runtime_minutes"].clip(lower = low_limit, upper = upp_limit, inplace=True)

# %% [markdown]
# We can see have we have a lot of duplicates on the genre column. This can be an indication that our movies are of many genres and they appear several times within the records. We shall not drop the duplicates because it will help us get insight as we get deeper

# %% [markdown]
# Now our data is clean and we can work with it to answer certain questions
# We can check if our data is okay using .info()

# %%
tables_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   start_year       146144 non-null  int64
#  3   runtime_minutes  146144 non-null  float64
#  4   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.6+ MB

# %%
tables_basics.head()
# Out:
#     movie_id                    primary_title  start_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh        2013       125.000000
# 1  tt0066787  One Day Before the Rainy Season        2019       114.000000
# 2  tt0069049       The Other Side of the Wind        2018       122.000000
# 3  tt0069204                  Sabse Bada Sukh        2018        86.187247
# 4  tt0100275         The Wandering Soap Opera        2017        80.000000
#
#                  genres
# 0    Action,Crime,Drama
# 1       Biography,Drama
# 2                 Drama
# 3          Comedy,Drama
# 4  Comedy,Drama,Fantasy

# %% [markdown]
# First lets drop the null values so that we dont get errors while splitting the column

# %%
tables_basics.dropna(subset="genres", inplace=True)

# %% [markdown]
# 3. MOVIE_RATINGS

# %% [markdown]
# Lets dive deeper into understanding our other data that is related to our database "movie_basics" above. We shall interact with this data, understand, clean it and later join our two datasets to get further insight in our problem

# %%
#here we are querying our database to retrieve all records and fields from "movie_ratings table"
query = """
SELECT *
FROM movie_ratings;
"""
#we are changing our data into pandas dataFrame 
table_ratings = pd.read_sql(query, conn)

# %% [markdown]
# Looking at the first records of our dataset

# %%
#checking the first 5 and last 5 records
table_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# Looking how data set looks like

# %%
#getting summary information olumns
table_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Calculating summary statistics for numeric columns

# %%
#getting summary statistics of numeric columns
tables_basics.describe()
# Out:
#           start_year  runtime_minutes
# count  140736.000000    140736.000000
# mean     2014.613986        85.098582
# std         2.735569        19.963928
# min      2010.000000        45.000000
# 25%      2012.000000        75.000000
# 50%      2015.000000        86.187247
# 75%      2017.000000        95.000000
# max      2115.000000       125.000000

# %% [markdown]
# 3. "TMBD.MOVIES.CSV"

# %% [markdown]
# LOading our data set

# %%
#loading data set tmbd.movies
Movies = pd.read_csv("tmdb.movies.csv", index_col= 0)
Movies
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %% [markdown]
# Looking if "original_title" column and "title" column contain the same values

# %%
#checking whether "original_title" and "title" contain the same values
title = Movies["original_title"] == Movies["title"]
title
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 26512    True
# 26513    True
# 26514    True
# 26515    True
# 26516    True
# Length: 26517, dtype: bool

# %%
#dropping one column because they are similar
Movies.drop("title", axis= 1)
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %%
Movies
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %% [markdown]
# comparing release date and popularity using time series plot

# %% [markdown]
# Here we are checking the popularity of movies as time goes over by in terms of years

# %%
Movies["release_date"] = pd.to_datetime(Movies["release_date"])
Movies.set_index("release_date", inplace= True)

# %%
Movies.head()
# Out:
#                         genre_ids     id original_language  \
# release_date
# 2010-11-19        [12, 14, 10751]  12444                en
# 2010-03-26    [14, 12, 16, 10751]  10191                en
# 2010-05-07          [12, 28, 878]  10138                en
# 1995-11-22        [16, 35, 10751]    862                en
# 2010-07-16          [28, 878, 12]  27205                en
#
#                                             original_title  popularity  \
# release_date
# 2010-11-19    Harry Potter and the Deathly Hallows: Part 1      33.533
# 2010-03-26                        How to Train Your Dragon      28.734
# 2010-05-07                                      Iron Man 2      28.515
# 1995-11-22                                       Toy Story      28.005
# 2010-07-16                                       Inception      27.920
#
#                                                      title  vote_average  \
# release_date
# ...

# %%
plt.figure(figsize=(20,8))
plt.plot(Movies.index, Movies["popularity"], label = "value", linestyle = "-", color = "orange", marker = "x")

plt.xlabel("release_date")
plt.ylabel("popularity")
plt.title("Release_date popularity time_series plot")
plt.show()

# %% [markdown]
# changing the name of original title to primary title in order to use it join table_basics

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26517 entries, 2010-11-19 to 2018-10-05
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   title              26517 non-null  object
#  6   vote_average       26517 non-null  float64
#  7   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# 4. MOVIE_INFO

# %%
info = pd.read_csv("rt.movie_info.tsv", delimiter="\t", index_col=0)
info.head()
# Out:
#                                              synopsis rating  \
# id
# 1   This gritty, fast-paced, and innovative police...      R
# 3   New York City, not-too-distant-future: Eric Pa...      R
# 5   Illeana Douglas delivers a superb performance ...      R
# 6   Michael Douglas runs afoul of a treacherous su...      R
# 7                                                 NaN     NR
#
#                                   genre          director  \
# id
# 1   Action and Adventure|Classics|Drama  William Friedkin
# 3     Drama|Science Fiction and Fantasy  David Cronenberg
# 5     Drama|Musical and Performing Arts    Allison Anders
# 6            Drama|Mystery and Suspense    Barry Levinson
# 7                         Drama|Romance    Rodney Bennett
#
#                              writer  theater_date      dvd_date currency  \
# id
# 1                    Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 3      David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1560 entries, 1 to 2000
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   synopsis      1498 non-null   object
#  1   rating        1557 non-null   object
#  2   genre         1552 non-null   object
#  3   director      1361 non-null   object
#  4   writer        1111 non-null   object
#  5   theater_date  1201 non-null   object
#  6   dvd_date      1201 non-null   object
#  7   currency      340 non-null    object
#  8   box_office    340 non-null    object
#  9   runtime       1530 non-null   object
#  10  studio        494 non-null    object
# dtypes: object(11)
# memory usage: 146.2+ KB

# %% [markdown]
# top_genres

# %%
#we use reset_index to make our index be in order
info.reset_index(drop=True, inplace=True)

# %%
info["runtime"] = info["runtime"].str.replace("minutes", '').astype(float)

# %%
low_quantile = info["runtime"].quantile(0.25)
upp_quantile = info["runtime"].quantile(0.75)

IQR = upp_quant - low_quant

low_lim = low_quantile - 1.5 * IQR
upp_lim = upp_quantile + 1.5 * IQR

info["runtime"].clip(lower = low_lim, upper = upp_lim, inplace=True)

# %% [markdown]
# relationship between rating and runtime

# %%
rating_run, ax = plt.subplots(figsize=(20, 8))
sns.scatterplot(x=info["runtime"], y = info["rating"])
plt.xticks(rotation = 45, size = 10)
plt.title("runtime against rating scatterplot  (info_table)")
plt.show()

# %%
# run_rating_corr = info["runtime"].corr(info["rating"])
# run_rating_corr

# %% [markdown]
# 5. BUDGETS

# %%
#loading the data
budgets = pd.read_csv("tn.movie_budgets.csv")
budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
budgets.set_index("id", inplace=True)

# %%
budgets.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
#checking the distribution of our dataset
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %% [markdown]
# compairing popularity with runtime_minutes

# %% [markdown]
# Compairing votecount against popularity

# %%
#creating scatter plot using seaborn and matplotlib
count_genre , ax = plt.subplots(figsize=(10,4))
sns.scatterplot(x= merging["popularity"], y = merging["vote_count"])
plt.xlabel("popularity")
plt.ylabel("vote_count")
plt.title(" popularity against vote_count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ezzy/Desktop/Phase1_project/index.ipynb Cell 94 line 3
#       <a href='vscode-notebook-cell:/home/ezzy/Desktop/Phase1_project/index.ipynb#Y310sZmlsZQ%3D%3D?line=0'>1</a> #creating scatter plot using seaborn and matplotlib
#       <a href='vscode-notebook-cell:/home/ezzy/Desktop/Phase1_project/index.ipynb#Y310sZmlsZQ%3D%3D?line=1'>2</a> count_genre , ax = plt.subplots(figsize=(10,4))
# ----> <a href='vscode-notebook-cell:/home/ezzy/Desktop/Phase1_project/index.ipynb#Y310sZmlsZQ%3D%3D?line=2'>3</a> sns.scatterplot(x= merging["popularity"], y = merging["vote_count"])
#       <a href='vscode-notebook-cell:/home/ezzy/Desktop/Phase1_project/index.ipynb#Y310sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel("popularity")
# ...
